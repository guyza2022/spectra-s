# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
binned_df = pd.read_csv('Binned Spectra/binned_raw_spectra.csv')

# %%
binned_df.head()
# Out:
#         2005.6       2006.6       2007.6       2008.6       2009.6  \
# 0  2555.248616  2492.952914  2448.851560  2558.521201  2401.285991
# 1  1578.573695  1778.665251  1726.931613  1587.898862  1545.504918
# 2  1129.944732  1075.744892  1126.467756  1075.311452  1165.752830
# 3  4500.115634  4506.589878  4526.849442  3963.104082  4399.852549
# 4  2016.797958  1851.484064  1932.506155  1961.980695  2031.301381
#
#         2010.6       2011.6       2012.6       2013.6       2014.6  ...  \
# 0  2432.952679  2468.548662  2368.582671  2362.008754  2478.270548  ...
# 1  1521.229487  1383.264049  1655.836988  1709.138734  1689.224426  ...
# 2  1265.077865  1197.455300  1140.686939  1094.059614  1137.376126  ...
# 3  4636.299881  4757.057797  4722.727727  4667.115738  4356.528251  ...
# 4  2179.652174  2460.484469  2386.879464  2163.735188  2112.932010  ...
#
#       19940.1     19941.7     19943.2     19944.8     19946.4     19948.1  \
# 0  181.282919  201.397806  201.370509  209.396809  219.516902  212.915716
# 1  125.693127  135.741589  132.679261  130.856651  148.723631  181.027783
# 2  108.612916  112.524766  109.859379  122.800323  134.542787  128.863480
# 3  274.279056  286.213040  305.861374  317.575662  325.871402  340.715783
# 4  264.707127  246.052000  230.826312  221.401550  226.441579  245.379276
#
#       19949.6     19951.2     19952.7  Serovar
# 0  222.264650  213.895397  201.930453    Agona
# 1  148.529205  130.664563  145.334380    Agona
# 2  131.522596  131.984655  134.042046    Agona
# 3  328.050799  362.352255  353.536022    Agona
# 4  252.294849  265.180241  269.944910    Agona
#
# [5 rows x 14377 columns]

# %%
n = 5
# define the colormap
cmap = plt.cm.jet
# extract all colors from the .jet map
cmaplist = [cmap(i) for i in range(cmap.N)]
# create the new map
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

# %%
spectra = binned_df.drop(columns=['Serovar'])
spectra.columns = spectra.columns.astype(float)
sample_index = 60
sample = spectra.iloc[sample_index,:]
sample_srv = binned_df['Serovar'][sample_index]

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot()
ax.plot(sample.index, sample.values, linewidth=1.2,c='b')
ax.tick_params(axis='x', labelsize=15, which='major', pad=7)
ax.tick_params(axis='y', labelsize=15, which='major', pad=7)
ax.tick_params(axis='x', length = 10, width = 1)
ax.tick_params(axis='x', which = 'minor', length = 5, width = 1)
ax.tick_params(axis='y', length = 10, width = 1)
ax.tick_params(axis='y', which = 'minor', length = 5, width = 1)
ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),2000))
ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),500), minor=True)
ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values+1000)//1000*1000),4000))
ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values)//1000*1000),2000), minor=True)
ax.set_xlim(min(sample.index),)
ax.set_ylim(min(sample.values),)
ax.set_xlabel('m/z',fontsize=18, fontweight='bold',labelpad = 10)
ax.set_ylabel('Intensity',fontsize=18, fontweight='bold',labelpad = 10)
ax.text(.8, .9, 'S. '+sample_srv, ha='right', va='top', transform=ax.transAxes, fontsize=25)
# Out:
# Text(0.8, 0.9, 'S. Albany')

# %%
#df = pd.read_csv('raw_spectra.csv')

# %%
#df.shape

# %%
# ori_spectra = df.drop(columns=['Serovar'])
# ori_spectra.columns = ori_spectra.columns.astype(float)
# sample_index = 60
# ori_sample = ori_spectra.iloc[sample_index,:]
# ori_sample_srv = df['Serovar'][sample_index]

# %%
# ori_sample.shape

# %%
# max(ori_sample.index)

# %%
# fig = plt.figure(figsize=(15,5))
# ax = fig.add_subplot()
# ax.plot(ori_sample.index, ori_sample.values, linewidth=1.2,c='m')
# ax.tick_params(axis='x', labelsize=15, which='major', pad=7)
# ax.tick_params(axis='y', labelsize=15, which='major', pad=7)
# ax.tick_params(axis='x', length = 10, width = 1)
# ax.tick_params(axis='x', which = 'minor', length = 5, width = 1)
# ax.tick_params(axis='y', length = 10, width = 1)
# ax.tick_params(axis='y', which = 'minor', length = 5, width = 1)
# ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),2000))
# ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),500), minor=True)
# ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values+1000)//1000*1000),4000))
# ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values)//1000*1000),2000), minor=True)
# ax.set_xlim(min(sample.index),)
# ax.set_ylim(min(sample.values),)
# ax.set_xlabel('m/z',fontsize=18, fontweight='bold',labelpad = 10)
# ax.set_ylabel('Intensity',fontsize=18, fontweight='bold',labelpad = 10)
# ax.text(.8, .9, 'S. '+sample_srv, ha='right', va='top', transform=ax.transAxes, fontsize=25)

# %% [markdown]
# ## 5 Classes Samples

# %%
sample_indexes = [0,40,80,120,160]
sample_srv = [binned_df['Serovar'][x] for x in sample_indexes]
spectra.columns = spectra.columns.astype(float)
colors = ['r','g','b','m','orange']

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot()
for i, sample_index in enumerate(sample_indexes):
    sample = spectra.iloc[sample_index,:]
    ax.plot(sample.index, sample.values, linewidth=1.2,c=colors[i],alpha=0.8,label=sample_srv[i])
ax.tick_params(axis='x', labelsize=15, which='major', pad=7)
ax.tick_params(axis='y', labelsize=15, which='major', pad=7)
ax.tick_params(axis='x', length = 10, width = 1)
ax.tick_params(axis='x', which = 'minor', length = 5, width = 1)
ax.tick_params(axis='y', length = 10, width = 1)
ax.tick_params(axis='y', which = 'minor', length = 5, width = 1)
ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),2000))
ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),500), minor=True)
ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values+1000)//1000*1000),4000))
ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values)//1000*1000),2000), minor=True)
ax.set_xlim(min(sample.index),)
ax.set_ylim(min(sample.values),)
ax.set_xlabel('m/z',fontsize=18, fontweight='bold',labelpad = 10)
ax.set_ylabel('Intensity',fontsize=18, fontweight='bold',labelpad = 10)
#ax.text(.8, .9, 'S. '+sample_srv, ha='right', va='top', transform=ax.transAxes, fontsize=25)
ax.legend()

# %%
for i, sample_index in enumerate(sample_indexes):
    fig = plt.figure(figsize=(15,5))
    ax = fig.add_subplot()
    sample = spectra.iloc[sample_index,:]
    ax.plot(sample.index, sample.values, linewidth=1.2,c=colors[i],alpha=0.8,label=sample_srv[i])
    ax.tick_params(axis='x', labelsize=15, which='major', pad=7)
    ax.tick_params(axis='y', labelsize=15, which='major', pad=7)
    ax.tick_params(axis='x', length = 10, width = 1)
    ax.tick_params(axis='x', which = 'minor', length = 5, width = 1)
    ax.tick_params(axis='y', length = 10, width = 1)
    ax.tick_params(axis='y', which = 'minor', length = 5, width = 1)
    ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),2000))
    ax.set_xticks(np.arange(min((sample.index//1000)*1000),max((sample.index+1000)//1000*1000),500), minor=True)
    ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values+1000)//1000*1000),4000))
    ax.set_yticks(np.arange(min((sample.values//1000)*1000),max((sample.values)//1000*1000),2000), minor=True)
    ax.set_xlim(min(sample.index),)
    ax.set_ylim(min(sample.values),)
    ax.set_xlabel('m/z',fontsize=18, fontweight='bold',labelpad = 10)
    ax.set_ylabel('Intensity',fontsize=18, fontweight='bold',labelpad = 10)
    ax.text(.8, .9, 'S. '+sample_srv[i], ha='right', va='top', transform=ax.transAxes, fontsize=25)
